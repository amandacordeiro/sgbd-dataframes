# %% [markdown]
# **Instalação das bibliotecas que serão utilizadas**

# %%
# !pip install pandas
# !pip install sqlalchemy
# !pip install pymysql

# %% [markdown]
# **Importação das bibliotecas necessárias para o desenvolvimento da etapa 5**

# %%
import pandas as pd
import sqlalchemy

# %% [markdown]
# **Criando a conexao com o banco de dados MySQL,
# Sintaxe da engine de Conexão ao Banco de Dados MySQL:**
#     engine = sqlalchemy.create_engine('mysql+drive://usuario:senha@ip-servidor:porta/banco-de-dados')

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://root:admin12345@localhost:3306/livraria_queiroz')

# %% [markdown]
# **Lendo as tabelas do banco de dados e tranformando em DataFrame"CUIDADO COM A QUANTIDADE DE REGISTROS DAS TABELAS, POIS PODE DEMORAR MUITO PARA CRIAR UM DATA-FRAME PODENDO ATE MESMO TRAVAR O BD OU JUPYTER NOTEBOOK"**

# %%
DF_CLIENTE = pd.read_sql_table('cliente',engine)
DF_FORNECEDORES = pd.read_sql_table('fornecedores',engine)
DF_FUNCIONARIO = pd.read_sql_table('funcionario',engine)
DF_PEDIDO_VENDA = pd.read_sql_table('pedido_venda',engine)
DF_PEDIDO_VENDA_HAS_PRODUTO = pd.read_sql_table('pedido_venda_has_produto',engine)
DF_PRODUTO = pd.read_sql_table('produto',engine)
DF_TELEFONE = pd.read_sql_table('telefone',engine)

# %% [markdown]
# **Desenvolvimento das consultas da Tabela 1 do projeto geral BD PUC**

# %% [markdown]
# **Q01 Efetivar cadastro cliete**

# %%
DF_CLIENTE = DF_CLIENTE.append({'NR_CPF' : '12345678911', 'DS_NOME' : 'FREDERIO MARTINS' , 'DS_SEXO' : 'M', 'DT_NASCIMENTO' : '1991-06-25' , 'DS_EMAIL' : 'fred.critica@gmail.com' , 'DS_SENHA' : 'admin12345', 'NR_CEP' : 30184018 , 'DS_ENDERECO' : 'RUA DOS ALPES' , 'NR_NUM' : 15 , 'DS_BAIRRO' : 'CAMPO ALTO' , 'DS_COMPLEMENTO' : 'AP-305' }, ignore_index=True)
# Out:
# C:\Users\FREDER~1\AppData\Local\Temp/ipykernel_24600/1899020455.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DF_CLIENTE = DF_CLIENTE.append({'NR_CPF' : '12345678911', 'DS_NOME' : 'FREDERIO MARTINS' , 'DS_SEXO' : 'M', 'DT_NASCIMENTO' : '1991-06-25' , 'DS_EMAIL' : 'fred.critica@gmail.com' , 'DS_SENHA' : 'admin12345', 'NR_CEP' : 30184018 , 'DS_ENDERECO' : 'RUA DOS ALPES' , 'NR_NUM' : 15 , 'DS_BAIRRO' : 'CAMPO ALTO' , 'DS_COMPLEMENTO' : 'AP-305' }, ignore_index=True)

# %% [markdown]
# **Q02 Alterar cadastro cliete**

# %%
DF_CLIENTE.loc[DF_CLIENTE.NR_CPF == '12345678911', 'NR_CPF'] = '12345678912'

# %% [markdown]
# **Q03 Consultar produtos por autor**

# %%
DF_PRODUTO.loc[DF_PRODUTO['DS_AUTOR'].str.contains('Martin J. W.')]
# Out:
#    NR_ISBN                                          DS_NOME  \
# 0      522  Stability of microstructure in metallic systems
#
#           DS_CATEGORIA                  DS_EDITORA      DS_AUTOR  \
# 0  Crime|Drama|Romance  Cambridge University Press  Martin J. W.
#
#                  DS_DESCRICAO DS_IDIOMA DS_FORMA_CP DS_EDICAO  NR_PAG  \
# 0   dui vel sem sed sagittis     Alemão     Digital   2nd ed.     696
#
#    VLR_COMPRA  QTDE_PRODUTO  FK_NR_FUNCIO
# 0       55.65           161             4

# %% [markdown]
# **Q04 Consultar produtos por descrição**

# %%
DF_PRODUTO.loc[DF_PRODUTO['DS_DESCRICAO'].str.contains('dui vel sem sed sagittis')]
# Out:
#    NR_ISBN                                          DS_NOME  \
# 0      522  Stability of microstructure in metallic systems
#
#           DS_CATEGORIA                  DS_EDITORA      DS_AUTOR  \
# 0  Crime|Drama|Romance  Cambridge University Press  Martin J. W.
#
#                  DS_DESCRICAO DS_IDIOMA DS_FORMA_CP DS_EDICAO  NR_PAG  \
# 0   dui vel sem sed sagittis     Alemão     Digital   2nd ed.     696
#
#    VLR_COMPRA  QTDE_PRODUTO  FK_NR_FUNCIO
# 0       55.65           161             4

# %% [markdown]
# **Q05 Consultar produtos por editora**

# %%
DF_PRODUTO.loc[DF_PRODUTO['DS_EDITORA'].str.contains('Cambridge')]
# Out:
#    NR_ISBN                                          DS_NOME  \
# 0      522  Stability of microstructure in metallic systems
#
#           DS_CATEGORIA                  DS_EDITORA      DS_AUTOR  \
# 0  Crime|Drama|Romance  Cambridge University Press  Martin J. W.
#
#                  DS_DESCRICAO DS_IDIOMA DS_FORMA_CP DS_EDICAO  NR_PAG  \
# 0   dui vel sem sed sagittis     Alemão     Digital   2nd ed.     696
#
#    VLR_COMPRA  QTDE_PRODUTO  FK_NR_FUNCIO
# 0       55.65           161             4

# %% [markdown]
# **Q06 Consultar produtos por preço**

# %%
DF_PRODUTO.loc[DF_PRODUTO['VLR_COMPRA'] < 100]
# Out:
#      NR_ISBN                                            DS_NOME  \
# 0        522    Stability of microstructure in metallic systems
# 1        978            Getulio Vargas nos folhetos de cordel :
# 3      97834                               Da senzala a colônia
# 4      97882                            Teorias do jornalismo :
# 5      97887             Física para cientistas e engenheiros :
# 6     971419         Metodologia cientifica em ciências sociais
# 8     978744                 A disssertação  clara e organizada
# 9    8120580                           A evoluçãodo capitalismo
# 10   8570413                                 Os Crimes do texto
# 12   9787530                                 Geografia agraria
# 13   9788577  Questões nacionais e regionais do território b...
# 14   9788590                            Materiais de construção
# 15  97885639                                     Processo civil
#
#                  DS_CATEGORIA                        DS_EDITORA  \
# ...

# %% [markdown]
# **Q07 Consultar produtos por formato**

# %%
DF_PRODUTO.loc[DF_PRODUTO['DS_FORMA_CP'] == "Digital"]
# Out:
#     NR_ISBN                                            DS_NOME  \
# 0       522    Stability of microstructure in metallic systems
# 2     92183          Mapas da geografia e cartografia temática
# 4     97882                            Teorias do jornalismo :
# 6    971419         Metodologia cientifica em ciências sociais
# 8    978744                 A disssertação  clara e organizada
# 11  9003437                  Economia brasileira contemporânea
# 13  9788577  Questões nacionais e regionais do território b...
# 14  9788590                            Materiais de construção
#
#                  DS_CATEGORIA                  DS_EDITORA  \
# 0         Crime|Drama|Romance  Cambridge University Press
# 2               Drama|Romance                    Contexto
# 4                       Drama             Traquina,Nelson
# 6                       Drama                       Atlas
# 8               Drama|Romance                 Ed. da UFPA
# ...

# %% [markdown]
# **Q08 Consultar produtos por idioma**

# %%
DF_PRODUTO.loc[DF_PRODUTO['DS_IDIOMA'].str.contains("Por")]
# Out:
#     NR_ISBN                                     DS_NOME      DS_CATEGORIA  \
# 2     92183   Mapas da geografia e cartografia temática     Drama|Romance
# 4     97882                     Teorias do jornalismo :             Drama
# 6    971419  Metodologia cientifica em ciências sociais             Drama
# 10  8570413                          Os Crimes do texto  Adventure|Comedy
#
#                           DS_EDITORA            DS_AUTOR  \
# 2                           Contexto  Martinelli Marcelo
# 4                    Traquina,Nelson             Insular
# 6                              Atlas          Demo Pedro
# 10  Figueiredo Vera Lúcia Follain de          Humanitas
#
#                               DS_DESCRICAO  DS_IDIOMA DS_FORMA_CP  \
# 2                     vestibulum a posuere  Portugues     Digital
# 4       quis odio consequat varius integer  Portugues     Digital
# 6           nunc donec quis orci eget orci  Portugues     Digital
# ...

# %% [markdown]
# **Q09 Consultar produtos por edição**

# %%
DF_PRODUTO.loc[DF_PRODUTO['DS_EDICAO'].str.contains("1")]
# Out:
#     NR_ISBN                                            DS_NOME  \
# 2     92183          Mapas da geografia e cartografia temática
# 6    971419         Metodologia cientifica em ciências sociais
# 7    978062                                Estatisitica  Facil
# 12  9787530                                 Geografia agraria
# 13  9788577  Questões nacionais e regionais do território b...
#
#                  DS_CATEGORIA         DS_EDITORA               DS_AUTOR  \
# 2               Drama|Romance           Contexto     Martinelli Marcelo
# 6                       Drama              Atlas             Demo Pedro
# 7                    Didático            Saraiva  Crespo, Antônio Arnot
# 12          Adventure|Fantasy  Expressão Popular          João Carveiró
# 13  Adventure|Children|Comedy  Expresão Popular          Matilda Mattos
#
#                        DS_DESCRICAO  DS_IDIOMA DS_FORMA_CP       DS_EDICAO  \
# 2              vestibulum a posuere  Portugues     Digital          1, ed.
# ...

# %% [markdown]
# **Q10 Consultar produtos por ISBN**

# %%
DF_PRODUTO.loc[DF_PRODUTO['NR_ISBN'] == 9788577]
# Out:
#     NR_ISBN                                            DS_NOME  \
# 13  9788577  Questões nacionais e regionais do território b...
#
#                  DS_CATEGORIA         DS_EDITORA        DS_AUTOR  \
# 13  Adventure|Children|Comedy  Expresão Popular   Matilda Mattos
#
#                        DS_DESCRICAO DS_IDIOMA DS_FORMA_CP DS_EDICAO  NR_PAG  \
# 13  san tortor quis turpis sed ante  Espanhol     Digital    1. ed.     571
#
#     VLR_COMPRA  QTDE_PRODUTO  FK_NR_FUNCIO
# 13       89.58           143             2

# %% [markdown]
# **Q11 Visualizar número do pedido**

# %%
DF_PEDIDO_VENDA.loc[DF_PEDIDO_VENDA['NR_PEDIDO'] == 23]
# Out:
#    NR_PEDIDO  VLR_VENDA  QTDE_VENDA            DT_VENDA    FK_NR_CPF  \
# 4         23     217.13           2 2003-06-20 20:00:00  02687747857
#
#    FK_NR_FUNC
# 4           5

# %% [markdown]
# **Q12 Inserir produtos no carrinho de compras**

# %%
DF_PEDIDO_VENDA = DF_PEDIDO_VENDA.append({'NR_PEDIDO' : 100, 'VLR_VENDA' : 118.36 , 'QTDE_VENDA' : 2, 'DT_VENDA' : '2022-05-29 11:55:31' , 'FK_NR_CPF' : '12345678912' , 'FK_NR_FUNC' : 1 }, ignore_index=True)
DF_PEDIDO_VENDA_HAS_PRODUTO = DF_PEDIDO_VENDA_HAS_PRODUTO.append({'PEDIDO_VENDA_NR_PEDIDO' : 100 , 'PEDIDO_VENDA_NR_FUNC' : 1 , 'PEDIDO_VENDA_NR_CPF' : '12345678912', 'PRODUTO_NR_ISBN' : 522, 'PRODUTO_NR_FUNCIONARIO' : 1}, ignore_index=True)
DF_PEDIDO_VENDA_HAS_PRODUTO = DF_PEDIDO_VENDA_HAS_PRODUTO.append({'PEDIDO_VENDA_NR_PEDIDO' : 100 , 'PEDIDO_VENDA_NR_FUNC' : 1 , 'PEDIDO_VENDA_NR_CPF' : '12345678912', 'PRODUTO_NR_ISBN' : 978, 'PRODUTO_NR_FUNCIONARIO' : 1}, ignore_index=True)
DF_PRODUTO.loc[DF_PRODUTO['NR_ISBN'] == 522, 'QTDE_PRODUTO'] = DF_PRODUTO.loc[DF_PRODUTO['NR_ISBN'] == 522, 'QTDE_PRODUTO'] -1
DF_PRODUTO.loc[DF_PRODUTO['NR_ISBN'] == 978, 'QTDE_PRODUTO'] = DF_PRODUTO.loc[DF_PRODUTO['NR_ISBN'] == 522, 'QTDE_PRODUTO'] -1
# Out:
# C:\Users\FREDER~1\AppData\Local\Temp/ipykernel_24600/4027529062.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DF_PEDIDO_VENDA = DF_PEDIDO_VENDA.append({'NR_PEDIDO' : 100, 'VLR_VENDA' : 118.36 , 'QTDE_VENDA' : 2, 'DT_VENDA' : '2022-05-29 11:55:31' , 'FK_NR_CPF' : '12345678912' , 'FK_NR_FUNC' : 1 }, ignore_index=True)
# C:\Users\FREDER~1\AppData\Local\Temp/ipykernel_24600/4027529062.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DF_PEDIDO_VENDA_HAS_PRODUTO = DF_PEDIDO_VENDA_HAS_PRODUTO.append({'PEDIDO_VENDA_NR_PEDIDO' : 100 , 'PEDIDO_VENDA_NR_FUNC' : 1 , 'PEDIDO_VENDA_NR_CPF' : '12345678912', 'PRODUTO_NR_ISBN' : 522, 'PRODUTO_NR_FUNCIONARIO' : 1}, ignore_index=True)
# ...

# %% [markdown]
# **Q13 Visualizar histórico de compras**

# %%
DF_JOIN = DF_PEDIDO_VENDA.join(DF_PEDIDO_VENDA_HAS_PRODUTO.set_index('PEDIDO_VENDA_NR_PEDIDO'), on='NR_PEDIDO', how="right")
DF_JOIN2 = DF_JOIN.join(DF_PRODUTO.set_index('NR_ISBN'), on='PRODUTO_NR_ISBN', how='inner')
DF_JOIN2.loc[DF_JOIN2['NR_PEDIDO'] == 100]
# Out:
#     NR_PEDIDO  VLR_VENDA  QTDE_VENDA             DT_VENDA    FK_NR_CPF  \
# 17        100     118.36           2  2022-05-29 11:55:31  12345678912
# 17        100     118.36           2  2022-05-29 11:55:31  12345678912
#
#     FK_NR_FUNC  PEDIDO_VENDA_NR_FUNC PEDIDO_VENDA_NR_CPF  PRODUTO_NR_ISBN  \
# 17           1                     1         12345678912              522
# 17           1                     1         12345678912              978
#
#     PRODUTO_NR_FUNCIONARIO  ...                  DS_EDITORA  \
# 17                       1  ...  Cambridge University Press
# 17                       1  ...                Editora UFPE
#
#                    DS_AUTOR                DS_DESCRICAO DS_IDIOMA DS_FORMA_CP  \
# 17             Martin J. W.   dui vel sem sed sagittis     Alemão     Digital
# 17  Cabral, Geovanni  Gomes          quam a odio in hac  Espanhol      Fisico
#
#                DS_EDICAO NR_PAG VLR_COMPRA  QTDE_PRODUTO  FK_NR_FUNCIO
# ...

# %% [markdown]
# **Q14 Consultar o estoque**

# %%
DF_PRODUTO
# Out:
#      NR_ISBN                                            DS_NOME  \
# 0        522    Stability of microstructure in metallic systems
# 1        978            Getulio Vargas nos folhetos de cordel :
# 2      92183          Mapas da geografia e cartografia temática
# 3      97834                               Da senzala a colônia
# 4      97882                            Teorias do jornalismo :
# 5      97887             Física para cientistas e engenheiros :
# 6     971419         Metodologia cientifica em ciências sociais
# 7     978062                                Estatisitica  Facil
# 8     978744                 A disssertação  clara e organizada
# 9    8120580                           A evoluçãodo capitalismo
# 10   8570413                                 Os Crimes do texto
# 11   9003437                  Economia brasileira contemporânea
# 12   9787530                                 Geografia agraria
# 13   9788577  Questões nacionais e regionais do território b...
# ...

# %% [markdown]
# **Q15 Consultar histórico de clientes**

# %%
DF_CLIENTE
# Out:
#          NR_CPF              DS_NOME DS_SEXO DT_NASCIMENTO  \
# 0   02687747857        Almir Queiroz       M           NaT
# 1   07087747451       Stormi Webster       F           NaT
# 2   08073695251      Floriano Mendes       M           NaT
# 3   08077747851       Joyce Meireles       F           NaT
# 4   11445268987          Bruno Dutra       M           NaT
# 5   11447747851      Lorena Oliveira       F           NaT
# 6   11665642450  Virgínia de la Mora       F           NaT
# 7   11987225851        Maria da Cruz       F           NaT
# 8   11998754576       Clarke Griffin       F           NaT
# 9   14841747851            Edes Lima       M           NaT
# 10  20687747551      Gabriela Franco       F           NaT
# 11  22335879761        Octavia Blake       F           NaT
# 12  22447596970        Afrânio Gomes       M           NaT
# 13  25670707851         Maria da Paz       F           NaT
# 14  25674747851     Edilaine Almeida       F           NaT
# ...

# %% [markdown]
# **Q16 Inserir produtos no estoque**

# %%
DF_PRODUTO = DF_PRODUTO.append({'NR_ISBN' : 9788580553635, 'DS_NOME' : 'PROJETO, DESENVOLVIMENTO DE APLICACOES & ADMINISTRACAO DE BANCO DE DADOS' , 'DS_CATEGORIA' : 'INFORMATICA', 'DS_EDITORA' : 'BOOKMAN' , 'DS_AUTOR' : 'Michael V. Mannino' , 'DS_DESCRICAO' : 'Este livro apresenta a base para entender a tecnologia de banco de dados. Estuda as tecnologias fundamentais de banco de dados para cada ambiente de processamento e discute o relacionamento de cada tecnologia com os avanços do comércio eletrônico e da computação corporativa. Essas características fazem deste livro-texto uma ferramenta essencial para aquele que pretende tornar-se um especialista em projeto e desenvolvimento de aplicações de banco de dados.', 'DS_IDIOMA' : 'Portugues' , 'DS_FORMA_CP' : 'Fisico' , 'DS_EDICAO' : '3ª ed' , 'NR_PAG' : 877 , 'VLR_COMPRA' : 116.51, 'QTDE_PRODUTO' : 15 , 'FK_NR_FUNCIO' : 4}, ignore_index=True)
# Out:
# C:\Users\FREDER~1\AppData\Local\Temp/ipykernel_24600/2931834315.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
DF_PRODUTO
# Out:
#           NR_ISBN                                            DS_NOME  \
# 0             522    Stability of microstructure in metallic systems
# 1             978            Getulio Vargas nos folhetos de cordel :
# 2           92183          Mapas da geografia e cartografia temática
# 3           97834                               Da senzala a colônia
# 4           97882                            Teorias do jornalismo :
# 5           97887             Física para cientistas e engenheiros :
# 6          971419         Metodologia cientifica em ciências sociais
# 7          978062                                Estatisitica  Facil
# 8          978744                 A disssertação  clara e organizada
# 9         8120580                           A evoluçãodo capitalismo
# 10        8570413                                 Os Crimes do texto
# 11        9003437                  Economia brasileira contemporânea
# 12        9787530                                 Geografia agraria
# ...

# %% [markdown]
# **Q17 Consultar produtos no estoque**

# %%
DF_PRODUTO.loc[DF_PRODUTO['NR_ISBN'] == 9788580553635]
# Out:
#           NR_ISBN                                            DS_NOME  \
# 16  9788580553635  PROJETO, DESENVOLVIMENTO DE APLICACOES & ADMIN...
#
#    DS_CATEGORIA DS_EDITORA            DS_AUTOR  \
# 16  INFORMATICA    BOOKMAN  Michael V. Mannino
#
#                                          DS_DESCRICAO  DS_IDIOMA DS_FORMA_CP  \
# 16  Este livro apresenta a base para entender a te...  Portugues      Fisico
#
#    DS_EDICAO  NR_PAG  VLR_COMPRA  QTDE_PRODUTO  FK_NR_FUNCIO
# 16     3ª ed     877      116.51          15.0             4

# %% [markdown]
# **Q18 Alterar produtos no estoque**

# %%
DF_PRODUTO.loc[DF_PRODUTO.NR_ISBN == 522, 'NR_ISBN'] = 979

# %% [markdown]
# **Q19 Consultar cadastro de fornecedores**

# %%
DF_FORNECEDORES[['NR_CNPJ', 'DS_NOME', 'FK_NR_FUNCIONARIO']]
# Out:
#            NR_CNPJ    DS_NOME  FK_NR_FUNCIONARIO
# 0   00000526812345    Youspan                  7
# 1   03052690000045   Cogilith                  6
# 2   03062503591245    Feedmix                  7
# 3   05858701021012  Rhynoodle                  7
# 4   08041457000123   Photojam                  6
# 5   11414700012401     Voonix                  6
# 6   14147700012445   Topdrive                  7
# 7   14256700001521  Edgepulse                  7
# 8   14787700012401     Camido                  6
# 9   14787700023457    Tagchat                  7
# 10  14787700457784   Edgeclub                  7
# 11  14787707470710    Jaxspan                  7
# 12  16686610012401    Cogidoo                  6
# 13  22623000104526     Trilia                  6
# 14  23598787871070       Omba                  7
# 15  30265888900001     Trudoo                  6
# 16  30698787512055   Brainbox                  6
# 17  39300010452357        Oba                  7
# ...

# %% [markdown]
# **Q20 Alterar cadastro de fornecedores**

# %%
DF_FORNECEDORES.loc[DF_FORNECEDORES.NR_CNPJ == "00000526812345", 'DS_NOME'] = "LIVRARIA G SA"

# %% [markdown]
# **Q21 Inserir cadastro de funcionários**

# %%
DF_FUNCIONARIO = DF_FUNCIONARIO.append({'NR_FUNCIONARIO' : 8, 'DS_CARGO' : 'Gerente' , 'DS_NOME' : 'Amanda Cordeiro', 'NR_CEP' : '8789876' , 'DS_ENDERECO' : 'Rua John Lennon' , 'NR_NUM' : '550' , 'DS_BAIRRO' : 'Messejana' , 'DS_COMPLEMENTO' : 'Condomínio'}, ignore_index=True)
# Out:
# C:\Users\FREDER~1\AppData\Local\Temp/ipykernel_24600/1794492082.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DF_FUNCIONARIO = DF_FUNCIONARIO.append({'NR_FUNCIONARIO' : 8, 'DS_CARGO' : 'Gerente' , 'DS_NOME' : 'Amanda Cordeiro', 'NR_CEP' : '8789876' , 'DS_ENDERECO' : 'Rua John Lennon' , 'NR_NUM' : '550' , 'DS_BAIRRO' : 'Messejana' , 'DS_COMPLEMENTO' : 'Condomínio'}, ignore_index=True)

# %% [markdown]
# **Q22 Consultar cadastro de funcionários**

# %%
DF_FUNCIONARIO[['NR_FUNCIONARIO', 'DS_NOME', 'DS_CARGO']]
# Out:
#    NR_FUNCIONARIO           DS_NOME     DS_CARGO
# 0               1   Talita Caroline  vendedor(a)
# 1               2    Bruna Giovanna  vendedor(a)
# 2               3     Tadeu Almeida  vendedor(a)
# 3               4  Gabriel Meireles  vendedor(a)
# 4               5   Juliana Brandão        Caixa
# 5               6  Rafael Cicarolli      Gerente
# 6               7   Aurélia Bagagin   Supervisor
# 7               8   Amanda Cordeiro      Gerente

# %% [markdown]
# **Q23 Alterar cadastro de funcionários**

# %%
DF_FUNCIONARIO.loc[DF_FUNCIONARIO.NR_FUNCIONARIO == 1, ['NR_NUM']] = 28

# %% [markdown]
# **Q24 Visualizar vendas geral da loja**

# %%
DF_PEDIDO_VENDA_HAS_PRODUTO
# Out:
#    PEDIDO_VENDA_NR_PEDIDO  PEDIDO_VENDA_NR_FUNC PEDIDO_VENDA_NR_CPF  \
# 0                       1                     3         755942719-7
# 1                     100                     1         12345678912
# 2                     100                     1         12345678912
#
#    PRODUTO_NR_ISBN  PRODUTO_NR_FUNCIONARIO
# 0          9787530                       1
# 1              522                       1
# 2              978                       1

# %% [markdown]
# **Q25 Visualizar vendas por cliente**

# %%
DF_V_CLI = DF_CLIENTE.join(DF_PEDIDO_VENDA.set_index('FK_NR_CPF'), on='NR_CPF', how='inner')
DF_V_CLI[['NR_CPF', 'DS_NOME', 'NR_PEDIDO', 'VLR_VENDA', 'DT_VENDA']]
# Out:
#          NR_CPF              DS_NOME  NR_PEDIDO  VLR_VENDA  \
# 0   02687747857        Almir Queiroz         23     217.13
# 1   07087747451       Stormi Webster         63     280.02
# 1   07087747451       Stormi Webster         68     465.84
# 1   07087747451       Stormi Webster         99      31.57
# 5   11447747851      Lorena Oliveira         27     514.75
# 5   11447747851      Lorena Oliveira         64     174.78
# 5   11447747851      Lorena Oliveira         66     105.10
# 5   11447747851      Lorena Oliveira         75     339.11
# 5   11447747851      Lorena Oliveira         95     534.20
# 6   11665642450  Virgínia de la Mora         33     594.09
# 10  20687747551      Gabriela Franco         59     198.31
# 13  25670707851         Maria da Paz         10     107.30
# 14  25674747851     Edilaine Almeida         15     152.02
# 21  12345678912     FREDERIO MARTINS        100     118.36
#
#                DT_VENDA
# 0   2003-06-20 20:00:00
# 1   2006-03-20 20:00:00
# ...

# %% [markdown]
# **Q26 Visualizar vendas por categoria literária**

# %%
DF_PRODUTO.loc[DF_PRODUTO['DS_CATEGORIA'].str.contains("Adv")]
# Out:
#     NR_ISBN                                            DS_NOME  \
# 10  8570413                                 Os Crimes do texto
# 12  9787530                                 Geografia agraria
# 13  9788577  Questões nacionais e regionais do território b...
#
#                  DS_CATEGORIA                        DS_EDITORA  \
# 10           Adventure|Comedy  Figueiredo Vera Lúcia Follain de
# 12          Adventure|Fantasy                 Expressão Popular
# 13  Adventure|Children|Comedy                 Expresão Popular
#
#           DS_AUTOR                            DS_DESCRICAO  DS_IDIOMA  \
# 10      Humanitas    porta volutpat erat quisque erat eros  Portugues
# 12   João Carveiró           libero nullam sit amet turpis   Espanhol
# 13  Matilda Mattos         san tortor quis turpis sed ante   Espanhol
#
#    DS_FORMA_CP DS_EDICAO  NR_PAG  VLR_COMPRA  QTDE_PRODUTO  FK_NR_FUNCIO
# 10      Fisico    5. ed.     599       46.44         166.0             5
# ...

# %% [markdown]
# **Q27 Visualizar vendas pelo valor médio, máximo e mínimo**

# %%
Media = DF_PEDIDO_VENDA['VLR_VENDA'].mean()
Maxima = DF_PEDIDO_VENDA['VLR_VENDA'].max()
Minima = DF_PEDIDO_VENDA['VLR_VENDA'].min()

print("Valor Médio:R$:{}, Máximo:R$:{} e Mínimo:R$:{} de vendas".format(Media, Maxima , Minima))
# Out:
# Valor Médio:R$:294.3983333333333, Máximo:R$:594.09 e Mínimo:R$:31.57 de vendas

# %% [markdown]
# **Q28 Visualizar o valor médio de vendas**

# %%
Media = DF_PEDIDO_VENDA['VLR_VENDA'].mean()
print(f"Valor Médio de vendas:R$:{Media :.2f}")
# Out:
# Valor Médio de vendas:R$:294.40

# %% [markdown]
# **Q29 Visualizar o valor médio de vendas por cliente**

# %%
DF_V_M_P_CLI = DF_CLIENTE.join(DF_PEDIDO_VENDA.set_index('FK_NR_CPF'), on='NR_CPF', how='inner')

# %%
DF_V_M_P_CLI.groupby(['NR_CPF', 'DS_NOME']).mean()['VLR_VENDA']
# Out:
# NR_CPF       DS_NOME
# 02687747857  Almir Queiroz          217.130000
# 07087747451  Stormi Webster         259.143333
# 11447747851  Lorena Oliveira        333.588000
# 11665642450  Virgínia de la Mora    594.090000
# 12345678912  FREDERIO MARTINS       118.360000
# 20687747551  Gabriela Franco        198.310000
# 25670707851  Maria da Paz           107.300000
# 25674747851  Edilaine Almeida       152.020000
# Name: VLR_VENDA, dtype: float64

# %% [markdown]
# **Q30 Visualizar venda por sexo**

# %%
DF_V_M_P_CLI = DF_CLIENTE.join(DF_PEDIDO_VENDA.set_index('FK_NR_CPF'), on='NR_CPF', how='inner')
DF_V_M_P_CLI.loc[DF_V_M_P_CLI['DS_SEXO'] == 'F']
# Out:
#          NR_CPF              DS_NOME DS_SEXO DT_NASCIMENTO  \
# 1   07087747451       Stormi Webster       F           NaT
# 1   07087747451       Stormi Webster       F           NaT
# 1   07087747451       Stormi Webster       F           NaT
# 5   11447747851      Lorena Oliveira       F           NaT
# 5   11447747851      Lorena Oliveira       F           NaT
# 5   11447747851      Lorena Oliveira       F           NaT
# 5   11447747851      Lorena Oliveira       F           NaT
# 5   11447747851      Lorena Oliveira       F           NaT
# 6   11665642450  Virgínia de la Mora       F           NaT
# 10  20687747551      Gabriela Franco       F           NaT
# 13  25670707851         Maria da Paz       F           NaT
# 14  25674747851     Edilaine Almeida       F           NaT
#
#                      DS_EMAIL DS_SENHA    NR_CEP         DS_ENDERECO NR_NUM  \
# 1           stormiw@gmail.com   aw1214  30280610        rua da Bahia     25
# ...
